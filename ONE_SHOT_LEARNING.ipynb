# %% [markdown]
# <a href="https://colab.research.google.com/github/MTHNTS008/EEE4022S_FINAL_PROJECT_2019/blob/master/ONE_SHOT_LEARNING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###INSTALLATIONS

# %%
# !pip install Pillow==4.0.0
#!pip install PIL
#!pip install image
# Out:
# Collecting Pillow==4.0.0
#   Downloading https://files.pythonhosted.org/packages/37/e8/b3fbf87b0188d22246678f8cd61e23e31caa1769ebc06f1664e2e5fe8a17/Pillow-4.0.0-cp36-cp36m-manylinux1_x86_64.whl (5.6MB)
#      |████████████████████████████████| 5.6MB 6.3MB/s
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow==4.0.0) (0.46)
# ERROR: torchvision 0.4.0 has requirement pillow>=4.1.1, but you'll have pillow 4.0.0 which is incompatible.
# ERROR: scikit-image 0.15.0 has requirement pillow>=4.3.0, but you'll have pillow 4.0.0 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: Pillow
#   Found existing installation: Pillow 4.3.0
#     Uninstalling Pillow-4.3.0:
#       Successfully uninstalled Pillow-4.3.0
# Successfully installed Pillow-4.0.0

# %%
'''!pip install pillow
# !sudo pip install Pillow==2.6.0
'''
# !pip install scipy==1.2.1
# Out:
# Collecting scipy==1.2.1
#   Downloading https://files.pythonhosted.org/packages/7f/5f/c48860704092933bf1c4c1574a8de1ffd16bf4fde8bab190d747598844b2/scipy-1.2.1-cp36-cp36m-manylinux1_x86_64.whl (24.8MB)
#      |████████████████████████████████| 24.8MB 1.3MB/s
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.6/dist-packages (from scipy==1.2.1) (1.16.5)
# ERROR: scikit-image 0.15.0 has requirement pillow>=4.3.0, but you'll have pillow 4.0.0 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: scipy
#   Found existing installation: scipy 1.3.1
#     Uninstalling scipy-1.3.1:
#       Successfully uninstalled scipy-1.3.1
# Successfully installed scipy-1.2.1

# %% [markdown]
# ###Deleting files

# %%
#!ls
#!rm -r 'images_background_iv_2'
#!rm -r 'images_evaluation_2'

# !rm -r 'vis'

# %% [markdown]
# ###GETTING LOCAL FILES

# %%
from zipfile import ZipFile
#file_name = "validation.zip"
file_name = "densefuse_gray.zip"
file_name = "data.zip"
#file_name = "Model.zip"
#file_name = "IV_images Many.zip"
#file_name = "powerline ir and visible.zip"
#file_name = "\checkpoints.zip"

file_name = "images_background_iv_2.zip"
#file_name = "images_evaluation_2.zip"

#file_name = "images_evaluation_data.zip"

#file_name = "VIS.zip"
#file_name = "NIR.zip"


#file_name = "vis.zip"
#file_name = "nir.zip"
#file_name = "New folder.zip"

with ZipFile (file_name, 'r') as zip:
    zip.extractall()

# %% [markdown]
# ###IMPORT LIBRARIES

# %%
# Import Keras and other Deep Learning dependencies
from keras.models import Sequential
import time
from keras.optimizers import Adam
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from keras.models import Model
import seaborn as sns
from keras.layers.normalization import BatchNormalization
from keras.layers.pooling import MaxPooling2D, AveragePooling2D
from keras.layers.merge import Concatenate
from keras.layers.core import Lambda, Flatten, Dense
from keras.initializers import glorot_uniform
from sklearn.preprocessing import LabelBinarizer
from keras.optimizers import *
from keras.engine.topology import Layer
from keras import backend as K
from keras.regularizers import l2
K.set_image_data_format('channels_last')
import cv2
import os
from skimage import io
import numpy as np
from numpy import genfromtxt
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

import numpy.random as rng
from sklearn.utils import shuffle


# %matplotlib inline
# %load_ext autoreload
# %reload_ext autoreload

#np.set_printoptions(threshold=np.nan)

from tqdm import tqdm
from keras import regularizers

import pickle

from PIL import Image
import imageio
from scipy import misc
import scipy
from scipy.misc.pilutil import imread, imsave, imresize


import skimage.io
import sys
import numpy as np
import pandas as pd
from scipy.misc import imread
import pickle
import os
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2
import time

import tensorflow as tf
from keras.models import Sequential
from keras.optimizers import Adam
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from keras.models import Model

from keras.layers.normalization import BatchNormalization
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import Concatenate
from keras.layers.core import Lambda, Flatten, Dense
from keras.initializers import glorot_uniform

from keras.engine.topology import Layer
from keras.regularizers import l2
from keras import backend as K

from sklearn.utils import shuffle

import numpy.random as rng
import glob

from keras.layers import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ##MODEL

# %%
def one_shot(i_shape):
    left_image = Input(i_shape)
    right_image = Input(i_shape)
   
    model = Sequential()
    model.add(Conv2D(64, (10,10), activation='relu', input_shape=i_shape, kernel_initializer='random_uniform', kernel_regularizer = regularizers.l2(2e-4)))
    model.add(MaxPooling2D())
    model.add(Conv2D(128, (7,7), activation='relu',
                     kernel_initializer='random_uniform',
                     bias_initializer= 'zeros', kernel_regularizer= regularizers.l2(2e-4)))
    model.add(MaxPooling2D())
    model.add(Conv2D(128, (4,4), activation='relu', kernel_initializer='random_uniform',
                     bias_initializer= 'zeros', kernel_regularizer= regularizers.l2(2e-4)))
    model.add(MaxPooling2D())
    model.add(Conv2D(256, (4,4), activation='relu', kernel_initializer='random_uniform',
                     bias_initializer= 'zeros', kernel_regularizer= regularizers.l2(2e-4)))
    model.add(Flatten())
    model.add(Dense(4096, activation='sigmoid',
                   kernel_regularizer= regularizers.l2(1e-3),
                   kernel_initializer='random_uniform',bias_initializer= 'zeros'))
    Left_tensor = model(left_image)
    Right_tensor = model(right_image)
    L1 = Lambda(lambda tensors:K.abs(tensors[0] - tensors[1]))
    loss_fcn = L1([Left_tensor, Right_tensor])
    predt = Dense(1,activation='sigmoid',bias_initializer= 'zeros')(loss_fcn)
    similarity = Model(inputs=[left_image,right_image],outputs=predt)
    return similarity

# %%
model = one_shot((128, 128, 3))
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# sequential_2 (Sequential)       (None, 4096)         68320576    input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 4096)         0           sequential_2[1][0]
#                                                                  sequential_2[2][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            4097        lambda_2[0][0]
# ==================================================================================================
# Total params: 68,324,673
# Trainable params: 68,324,673
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### SECOND

# %%
def get_siamese_model2(input_shape):
    left_input = Input(input_shape)
    right_input = Input(input_shape)
    model1 = Sequential()
    model1.add(Conv2D(64, (3,3), activation = 'relu',input_shape=input_shape, padding = 'same', kernel_initializer = 'he_normal'))
    
    model1.add(Dropout(0.05))
    model1.add(MaxPooling2D(pool_size=(2, 2)))

    model1.add(Conv2D(128, (3,3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal'))
   
    model1.add(Dropout(0.05))
    model1.add(MaxPooling2D(pool_size=(2, 2)))

    model1.add(Conv2D(256, (3,3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal'))
   
    model1.add(Dropout(0.05))
    model1.add(MaxPooling2D(pool_size=(2, 2)))

    model1.add(Conv2D(512, (3,3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal'))
    
    model1.add(Dropout(0.05))
    model1.add(MaxPooling2D(pool_size=(2, 2)))

    model1.add(Conv2D(1024, (3,3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal'))
    
    
    encoded_l = model(left_input)
    encoded_r = model(right_input)
    L1_layer = Lambda(lambda tensors:K.abs(tensors[0] - tensors[1]))
    L1_distance = L1_layer([encoded_l, encoded_r])
    prediction = Dense(1,activation='sigmoid',bias_initializer= 'zeros')(L1_distance)
    siamese_net2 = Model(inputs=[left_input,right_input],outputs=prediction)
    return siamese_net2

# %% [markdown]
# ###PLOTTING ARCHITECHTURE

# %%
'''import pydot
from keras.utils import plot_model
from IPython.display import SVG
import keras.utils.vis_utils 
from keras.utils.vis_utils import model_to_dot
plot_model(model, to_file='model.png')
SVG(model_to_dot(model).create(prog='dot', format='svg'))'''

# %%
import pydot
from keras.utils import plot_model
from IPython.display import SVG
import keras.utils.vis_utils 
from keras.utils.vis_utils import model_to_dot

plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ###LOADING DATASET

# %%
train_folder = "/content/images_background_iv_2/"
val_folder = '/content/images_evaluation_2/'
save_path = '/content/'

# %%
def loadimgs(path,n = 0):
    '''
    path => Path of train directory
    '''
    X=[]
    y = []
    cat_dict = {}
    image_dict = {}
    curr_y = n
    image_list1 =[]
    
    #DIR = path + letter + '/'


    
    # we load every alphabet seperately so we can isolate them later
    for alphabet in os.listdir(path):
        print("loading alphabet: " + alphabet)        
        image_dict[alphabet] = [curr_y,None]
        alphabet_path = os.path.join(path,alphabet)
        print('alphabet_path',alphabet_path)
        
        # every letter/category has it's own column in the array, so  load seperately
        for letter in os.listdir(alphabet_path):
            DIR = alphabet_path + '/' + letter + '/'
            print('letter',letter)
            cat_dict[curr_y] = (alphabet, letter)
            category_images = []
            letter_path = os.path.join(alphabet_path, letter)           
            '''#\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\
            batch_x = gen_batches(DIR,{'batch_size': config['batch_size'],'image_size': config['image_size'], 'shuffle_batch': config['shuffle_batch']})
            print('Start....')
            #sess = tf.Session()
            #_bx, = sess.run([batch_x])
            #sess.run(tf.global_variables_initializer())
            print('BATCH:',_bx.shape)'''
            #\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\'''
      
            #read all the images in the current category
            for filename in tqdm((glob.glob(DIR + '*.bmp'))):
            #for filename in tqdm((glob.glob(DIR + '*.png'))):
            
                src=cv2.imread(filename)
                dst1 = cv2.cvtColor(src, cv2.COLOR_BGR2RGB)
                
                patch = np.copy(dst1[10:10+128,10:10+128])
                #patches = image.extract_patches_2d(one_image, (128, 128))
                #patch = extractPatches(dst, '/content/')
                #img = Resize(dst)            
                
                '''image_path = os.path.join(letter_path, filename)                
                image = imread(image_path) '''  
                #vis = get_image(filename, 256, 256,'L')
                image_list1.append(patch)
                dataset1 = np.array(image_list1)               
                category_images.append(patch)
                y.append(curr_y)
            try:
                X.append(np.stack(category_images))
            # edge case  - last one
            except ValueError as e:
                print(e)
                print("error - category_images:", category_images)
                
            curr_y += 1
            image_dict[alphabet][1] = curr_y - 1           
    
        
    y = np.vstack(y)
    X = np.stack(X)
    print(dataset1.shape)
    print()
    
    return X,y,image_dict

# %% [markdown]
# ###LOAD IMAGES

# %%
Xval,yval,cval=loadimgs(val_folder)
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 28.56it/s]
# 100%|██████████| 2/2 [00:00<00:00, 110.67it/s]
# 100%|██████████| 2/2 [00:00<00:00, 122.85it/s]
# 100%|██████████| 2/2 [00:00<00:00, 128.15it/s]
# 100%|██████████| 2/2 [00:00<00:00, 168.63it/s]
# 100%|██████████| 2/2 [00:00<00:00, 162.96it/s]
# 100%|██████████| 2/2 [00:00<00:00, 121.03it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# loading alphabet: Validate
# alphabet_path /content/images_evaluation_2/Validate
# letter New folder (4)
# letter character15 - Copy
# letter New folder (6)
# letter character20
# letter character19
# letter New folder (5)
# letter character15
# letter character17 - Copy
# 100%|██████████| 2/2 [00:00<00:00, 146.61it/s]
# 100%|██████████| 2/2 [00:00<00:00, 165.97it/s]
# 100%|██████████| 2/2 [00:00<00:00, 173.27it/s]
# 100%|██████████| 2/2 [00:00<00:00, 124.10it/s]
# 100%|██████████| 2/2 [00:00<00:00, 157.62it/s]
# 100%|██████████| 2/2 [00:00<00:00, 170.17it/s]
# 100%|██████████| 2/2 [00:00<00:00, 160.81it/s]
# 100%|██████████| 2/2 [00:00<00:00, 79.64it/s]
# 100%|██████████| 2/2 [00:00<00:00, 163.38it/s]
# 100%|██████████| 2/2 [00:00<00:00, 162.43it/s]
# 100%|██████████| 2/2 [00:00<00:00, 178.74it/s]
# letter character18
# letter character16 - Copy
# letter character20 - Copy
# letter character18 - Copy
# letter New folder (3)
# letter character17
# letter New folder
# letter New folder (2)
# letter character16
# letter character19 - Copy
# (36, 128, 128, 3)

# %%
Xval.shape
# Out:
# (18, 2, 128, 128, 3)

# %%
X,y,c = loadimgs(train_folder)
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 110.37it/s]
# 100%|██████████| 2/2 [00:00<00:00, 210.56it/s]
# 100%|██████████| 2/2 [00:00<00:00, 108.70it/s]
# 100%|██████████| 2/2 [00:00<00:00, 411.91it/s]
# 100%|██████████| 2/2 [00:00<00:00, 466.01it/s]
# 100%|██████████| 2/2 [00:00<00:00, 333.74it/s]
# 100%|██████████| 2/2 [00:00<00:00, 113.92it/s]
# 100%|██████████| 2/2 [00:00<00:00, 148.28it/s]
# 100%|██████████| 2/2 [00:00<00:00, 255.31it/s]
# 100%|██████████| 2/2 [00:00<00:00, 118.54it/s]
# 100%|██████████| 2/2 [00:00<00:00, 171.70it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# loading alphabet: IMAGES
# alphabet_path /content/images_background_iv_2/IMAGES
# letter character13 - Copy (2)
# letter character07
# letter character14 - Copy (2)
# letter character01 - Copy
# letter character11 - Copy
# letter character05
# letter character14 - Copy
# letter character02 - Copy (2)
# letter character07 - Copy
# letter character06 - Copy
# letter character03 - Copy (2)
# letter character02 - Copy
# 100%|██████████| 2/2 [00:00<00:00, 145.27it/s]
# 100%|██████████| 2/2 [00:00<00:00, 185.73it/s]
# 100%|██████████| 2/2 [00:00<00:00, 93.51it/s]
# 100%|██████████| 2/2 [00:00<00:00, 94.08it/s]
# 100%|██████████| 2/2 [00:00<00:00, 328.45it/s]
# 100%|██████████| 2/2 [00:00<00:00, 118.86it/s]
# 100%|██████████| 2/2 [00:00<00:00, 216.74it/s]
# 100%|██████████| 2/2 [00:00<00:00, 162.53it/s]
# 100%|██████████| 2/2 [00:00<00:00, 288.85it/s]
# 100%|██████████| 2/2 [00:00<00:00, 157.67it/s]
# 100%|██████████| 2/2 [00:00<00:00, 331.85it/s]
# 100%|██████████| 2/2 [00:00<00:00, 303.53it/s]
# 100%|██████████| 2/2 [00:00<00:00, 113.52it/s]
# letter character03 - Copy
# letter character10 - Copy (2)
# letter character14
# letter character05 - Copy (2)
# letter character09 - Copy
# letter character07 - Copy (2)
# letter character12
# letter character01
# letter character04 - Copy (2)
# letter character11
# letter character11 - Copy (2)
# letter character06
# 100%|██████████| 2/2 [00:00<00:00, 131.62it/s]
# 100%|██████████| 2/2 [00:00<00:00, 215.03it/s]
# 100%|██████████| 2/2 [00:00<00:00, 108.33it/s]
# 100%|██████████| 2/2 [00:00<00:00, 158.30it/s]
# 100%|██████████| 2/2 [00:00<00:00, 112.07it/s]
# 100%|██████████| 2/2 [00:00<00:00, 149.58it/s]
# 100%|██████████| 2/2 [00:00<00:00, 113.14it/s]
# 100%|██████████| 2/2 [00:00<00:00, 309.68it/s]
# 100%|██████████| 2/2 [00:00<00:00, 265.36it/s]
# 100%|██████████| 2/2 [00:00<00:00, 108.75it/s]
# 100%|██████████| 2/2 [00:00<00:00, 111.50it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# letter character02
# letter character08 - Copy (2)
# letter character12 - Copy
# letter character13 - Copy
# letter character10
# letter character03
# letter character09 - Copy (2)
# letter character05 - Copy
# letter character08
# letter character09
# letter character13
# letter character10 - Copy
# 100%|██████████| 2/2 [00:00<00:00, 100.49it/s]
# 100%|██████████| 2/2 [00:00<00:00, 223.22it/s]
# 100%|██████████| 2/2 [00:00<00:00, 146.13it/s]
# 100%|██████████| 2/2 [00:00<00:00, 93.35it/s]
# 100%|██████████| 2/2 [00:00<00:00, 126.46it/s]
# 100%|██████████| 2/2 [00:00<00:00, 137.67it/s]
# 100%|██████████| 2/2 [00:00<00:00, 230.09it/s]
# letter character01 - Copy (2)
# letter character12 - Copy (2)
# letter character06 - Copy (2)
# letter character04 - Copy
# letter character04
# letter character08 - Copy
# (84, 128, 128, 3)

# %%
X.shape
# Out:
# (42, 2, 128, 128, 3)

# %%
plt.imshow(X[3][1])

# %% [markdown]
# ###Saving the train tensors on disk

# %%
with open(os.path.join(save_path,"train.pickle"), "wb") as f:
    pickle.dump((X,c),f)

# %% [markdown]
# ###Saving the validation tensors on disk

# %%
with open(os.path.join(save_path,"val.pickle"), "wb") as f:
    pickle.dump((Xval,cval),f)

# %% [markdown]
# ###Loading the train tensors

# %%
with open(os.path.join(save_path, "train.pickle"), "rb") as f:
    (Xtrain, train_classes) = pickle.load(f)

# %%
with open(os.path.join(save_path, "val.pickle"), "rb") as f:
    (Xval, val_classes) = pickle.load(f)

# %%
def get_batch(batch_size,s="train"):
    """Create batch of n pairs, half same class, half different class"""
    if s == 'train':
        X = Xtrain
        categories = train_classes
    else:
        X = Xval
        categories = val_classes
    n_classes, n_examples, w, h, color = X.shape

    # randomly sample several classes to use in the batch
    categories = rng.choice(n_classes,size=(batch_size,),replace=False)
    
    # initialize 2 empty arrays for the input image batch
    pairs=[np.zeros((batch_size, h, w,3)) for i in range(2)]
    
    # initialize vector for the targets
    targets=np.zeros((batch_size,))
    
    # make one half of it '1's, so 2nd half of batch has same class
    targets[batch_size//2:] = 1
    for i in range(batch_size):
        category = categories[i]
        idx_1 = rng.randint(0, n_examples)
        pairs[0][i,:,:,:] = X[category, idx_1].reshape(w, h, 3)
        idx_2 = rng.randint(0, n_examples)
        
        # pick images of same class for 1st half, different for 2nd
        if i >= batch_size // 2:
            category_2 = category  
        else: 
            # add a random number to the category modulo n classes to ensure 2nd image has a different category
            category_2 = (category + rng.randint(1,n_classes)) % n_classes
        
        pairs[1][i,:,:,:] = X[category_2,idx_2].reshape(w, h, 3)
    
    return pairs, targets

# %%
def generate(batch_size, s="train"):
    """a generator for batches, so model.fit_generator can be used. """
    while True:
        pairs, targets = get_batch(batch_size,s)
        yield (pairs, targets)

# %%
def make_oneshot_task(N, s="val", language=None):
    """Create pairs of test image, support set for testing N way one-shot learning. """
    if s == 'train':
        X = Xtrain
        categories = train_classes
    else:
        X = Xval
        categories = val_classes
    n_classes, n_examples, w, h,color = X.shape
    
    indices = rng.randint(0, n_examples,size=(N,))
    if language is not None: # if language is specified, select characters for that language
        low, high = categories[language]
        if N > high - low:
            raise ValueError("This language ({}) has less than {} letters".format(language, N))
        categories = rng.choice(range(low,high),size=(N,),replace=False)

    else: # if no language specified just pick a bunch of random letters
        categories = rng.choice(range(n_classes),size=(N,),replace=False)            
    true_category = categories[0]
    ex1, ex2 = rng.choice(n_examples,replace=False,size=(2,))
    test_image = np.asarray([X[true_category,ex1,:,:]]*N).reshape(N, w, h, 3)
    support_set = X[categories,indices,:,:]
    support_set[0,:,:] = X[true_category,ex2]
    support_set = support_set.reshape(N, w, h, 3)
    targets = np.zeros((N,))
    targets[0] = 1
    targets, test_image, support_set = shuffle(targets, test_image, support_set)
    pairs = [test_image,support_set]

    return pairs, targets

# %%
def test_oneshot(model, N, k, s = "val", verbose = 0):
    """Test average N way oneshot learning accuracy of a siamese neural net over k one-shot tasks"""
    n_correct = 0
    if verbose:
        print("Evaluating model on {} random {} way one-shot learning tasks ... \n".format(k,N))
    for i in range(k):
        inputs, targets = make_oneshot_task(N,s)
        probs = model.predict(inputs)
        if np.argmax(probs) == np.argmax(targets):
            n_correct+=1
    percent_correct = (100.0 * n_correct / k)
    if verbose:
        print("Got an average of {}% {} way one-shot learning accuracy \n".format(percent_correct,N))
    return percent_correct

# %% [markdown]
# ###SET PARAMETERS

# %%
# Hyper parameters
evaluate_every = 1 # interval for evaluating on one-shot tasks
batch_size = 1
n_iter = 900 # No. of training Epochs
N_way = 2 # how many classes for testing one-shot tasks
n_val = 2 # how many one-shot tasks to validate on
best = -1

# %%
model_path = '/content/'

# %%
model = one_shot(( 128, 128 ,3))
#model.summary()

# %%
adam = Adam(lr = 0.00006)
model.compile(loss="binary_crossentropy",optimizer=adam)

# %%
print("Starting training process!")
print("-------------------------------------")
t_start = time.time()
for i in range(1, n_iter+1):
    (inputs,targets) = get_batch(batch_size)
    loss = model.train_on_batch(inputs, targets)
    if i % evaluate_every == 0:
        print("\n ------------- \n")
        #print("Time for {0} iterations: {1} mins".format(i, (time.time()-t_start)/60.0))
        print("Train Loss: {0}".format(loss)) 
        val_acc = test_oneshot(model, N_way, n_val, verbose=True)
        model.save_weights(os.path.join(model_path, 'weights.{}.h5'.format(i)))
        if val_acc >= best:
            print("Current best: {0}, previous best: {1}".format(val_acc, best))
            best = val_acc
# Out:
# Starting training process!
# -------------------------------------
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
#
#  -------------
#
# Train Loss: 56.82788848876953
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
# Current best: 0.0, previous best: -1
#
#  -------------
#
# Train Loss: 56.564659118652344
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
# Current best: 50.0, previous best: 0.0
#
#  -------------
#
# Train Loss: 56.17682647705078
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
# Current best: 50.0, previous best: 50.0
#
#  -------------
#
# Train Loss: 56.26319122314453
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
# Current best: 50.0, previous best: 50.0
#
#  -------------
#
# Train Loss: 56.0771598815918
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 55.89084243774414
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 55.70442581176758
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 55.51805114746094
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 55.33177947998047
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
# Current best: 50.0, previous best: 50.0
#
#  -------------
#
# Train Loss: 55.14570617675781
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 54.761390686035156
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
# Current best: 50.0, previous best: 50.0
#
#  -------------
#
# Train Loss: 54.781517028808594
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 54.603389739990234
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
# Current best: 50.0, previous best: 50.0
#
#  -------------
#
# Train Loss: 54.42550277709961
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
# Current best: 50.0, previous best: 50.0
#
#  -------------
#
# Train Loss: 54.24791717529297
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 54.070621490478516
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 53.8936653137207
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
# Current best: 50.0, previous best: 50.0
#
#  -------------
#
# Train Loss: 53.7170524597168
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 53.540809631347656
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 50.0
#
#  -------------
#
# Train Loss: 53.36494827270508
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 53.18946838378906
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 53.014408111572266
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 52.83976364135742
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 52.66554260253906
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 52.49176025390625
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 52.11355209350586
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 52.147117614746094
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 51.97626495361328
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Train Loss: 51.80586242675781
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 51.635929107666016
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 51.46646499633789
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 51.297454833984375
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 51.128936767578125
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 50.96089172363281
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 50.79332733154297
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 50.626243591308594
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 50.459659576416016
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 50.29355239868164
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 50.127933502197266
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 49.96282196044922
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 49.79819869995117
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 49.63406753540039
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 49.47043991088867
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 49.30731201171875
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 49.144683837890625
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 48.98255157470703
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 48.82091522216797
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 48.6597900390625
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 48.4991569519043
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 48.33902359008789
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 48.17940139770508
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 48.0202751159668
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 47.86164474487305
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 47.63461685180664
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 47.20529556274414
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 47.39314270019531
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Train Loss: 47.2392692565918
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 47.08586502075195
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 46.93294906616211
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 46.780517578125
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 46.62855911254883
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 46.477088928222656
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 46.32609939575195
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 46.175575256347656
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 46.02553939819336
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 45.770103454589844
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 45.728721618652344
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 45.58192443847656
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 45.435604095458984
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 45.28974151611328
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 45.14434814453125
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 44.99941635131836
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 44.85493850708008
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 44.710914611816406
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 44.567352294921875
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Train Loss: 44.42424774169922
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 44.28159713745117
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 44.139400482177734
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 43.997657775878906
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 43.85637283325195
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 43.64634323120117
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 43.576114654541016
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 43.43714904785156
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 43.01324462890625
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 43.16241455078125
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 43.02664566040039
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 42.891300201416016
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 42.75638198852539
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 42.62189865112305
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 42.48783493041992
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 42.35418701171875
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 42.22097396850586
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 42.08816909790039
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 41.95579147338867
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 41.82383728027344
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 41.692283630371094
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 41.53446578979492
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 41.4312629699707
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Train Loss: 41.30178451538086
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Train Loss: 41.17271423339844
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 41.0440559387207
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 40.915802001953125
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 40.69529342651367
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 40.661094665527344
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 40.53464126586914
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Train Loss: 40.408592224121094
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 40.28293991088867
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 40.15768814086914
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 40.10121154785156
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 39.9093132019043
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 39.78618240356445
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 39.66344451904297
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Train Loss: 39.486228942871094
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 39.30588150024414
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 39.15726089477539
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 39.178524017333984
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 39.058738708496094
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Train Loss: 38.939334869384766
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 38.666786193847656
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 38.7026252746582
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 38.58531188964844
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 38.4683723449707
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 38.351802825927734
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 38.23560333251953
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 38.11975860595703
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 38.00428771972656
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 37.8891716003418
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 37.66128158569336
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 37.66025924682617
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 37.54644775390625
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 37.43299865722656
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 37.319908142089844
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 37.20717239379883
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 37.09479522705078
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 36.982765197753906
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 36.87109375
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 36.759769439697266
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 36.64881134033203
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 36.53818893432617
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 36.42792892456055
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 36.31800842285156
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 36.20844268798828
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 35.72895812988281
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 35.78755569458008
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 35.459510803222656
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 35.7767219543457
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 35.67019271850586
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Train Loss: 35.56399917602539
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 35.0538330078125
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 35.35285568237305
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 35.247901916503906
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 35.143280029296875
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 35.03898620605469
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 34.935028076171875
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 34.83139419555664
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 34.72808837890625
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 34.6251106262207
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 34.29826736450195
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 34.420326232910156
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 34.18742752075195
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 34.21738052368164
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 34.11655044555664
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 34.01603698730469
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 33.91584014892578
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 33.81597137451172
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 33.707157135009766
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 33.61727523803711
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 33.51845932006836
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 33.254188537597656
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 33.27421951293945
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 33.22438430786133
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 33.127140045166016
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 33.030208587646484
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Train Loss: 32.93358612060547
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 32.8372688293457
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 32.74125671386719
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 32.645545959472656
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 32.55014419555664
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 32.55068588256836
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 32.360443115234375
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 32.296688079833984
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 32.172325134277344
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 32.07880783081055
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Train Loss: 31.98558807373047
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 31.892663955688477
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 31.80003547668457
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 31.707704544067383
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Train Loss: 31.615663528442383
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 31.523921966552734
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 31.43246841430664
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Train Loss: 31.341304779052734
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 31.25043296813965
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 31.16756820678711
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 30.931163787841797
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 30.980016708374023
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 30.89055633544922
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 30.80138397216797
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 30.71249771118164
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 30.623891830444336
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 30.367061614990234
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 30.447742462158203
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 30.360191345214844
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 30.27292251586914
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 30.011335372924805
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Train Loss: 30.099462509155273
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 30.013273239135742
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 29.69695281982422
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 29.84187889099121
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Train Loss: 29.756671905517578
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 29.67173957824707
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 29.32741928100586
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 29.252994537353516
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 29.419963836669922
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 29.33689308166504
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 29.25408935546875
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 29.154983520507812
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 29.08934211730957
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 29.007400512695312
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 28.925722122192383
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 28.84429931640625
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 28.763132095336914
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 28.68222427368164
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Train Loss: 28.60157585144043
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 28.52118492126465
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 28.441043853759766
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 28.361164093017578
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 28.281530380249023
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 28.20215606689453
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 28.123031616210938
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Train Loss: 28.044160842895508
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 27.96554183959961
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 27.63524627685547
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 27.74060821533203
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 27.653217315673828
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 27.65423011779785
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 27.577133178710938
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 27.500288009643555
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 27.423686981201172
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 27.32750129699707
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 27.27128791809082
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 27.195486068725586
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 27.119924545288086
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 27.04461097717285
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 26.96953582763672
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 26.894702911376953
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 26.82010841369629
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 26.745756149291992
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 26.671640396118164
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 26.59776496887207
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 26.524126052856445
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 26.444847106933594
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 26.377639770507812
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 26.30478858947754
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 26.2321720123291
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 26.159791946411133
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 26.087646484375
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 26.015735626220703
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Train Loss: 25.944053649902344
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 25.872604370117188
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 25.80138397216797
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 25.729900360107422
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Train Loss: 25.460508346557617
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 25.589385986328125
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.621955871582031
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.624914169311523
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.614778518676758
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.604676246643066
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.594608306884766
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.584573745727539
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Train Loss: 8.57457160949707
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.455571174621582
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.518340110778809
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.544780731201172
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.534920692443848
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.525092124938965
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.515298843383789
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.512540817260742
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.495808601379395
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Train Loss: 8.486116409301758
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.476456642150879
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.466829299926758
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.457232475280762
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.447668075561523
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.438135147094727
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.428631782531738
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.419160842895508
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.409719467163086
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.400308609008789
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.390929222106934
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.381580352783203
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.372260093688965
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.362972259521484
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.353713989257812
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.344486236572266
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.335287094116211
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.326118469238281
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Train Loss: 8.31697940826416
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.307870864868164
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.298789978027344
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Train Loss: 8.172174453735352
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.280729293823242
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.271749496459961
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.262799263000488
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.20278263092041
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.244994163513184
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.104524612426758
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.227310180664062
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.218511581420898
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.162362098693848
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.201017379760742
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.1923246383667
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Train Loss: 8.183661460876465
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.175030708312988
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.166425704956055
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.157851219177246
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.14930248260498
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.111736297607422
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.062546730041504
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.119736671447754
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.115399360656738
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.1069974899292
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.098620414733887
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.090271949768066
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.081948280334473
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Train Loss: 8.073651313781738
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 7.952208042144775
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.057135581970215
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.048916816711426
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Train Loss: 8.04072380065918
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.032556533813477
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.024415016174316
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 7.879007339477539
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.008208274841309
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 8.000144958496094
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 7.992107391357422
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 7.984094619750977
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 7.976106643676758
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 7.968143939971924
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 7.960206031799316
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 7.952292442321777
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 7.931550979614258
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 7.936544418334961
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 7.928709030151367
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 7.920897483825684
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 7.885458469390869
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 7.90535306930542
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 7.897616863250732
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 7.889906883239746
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 7.88222074508667
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 7.8530731201171875
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 7.823488712310791
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Train Loss: 7.859307765960693
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 7.851586818695068
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 50.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Train Loss: 7.844154357910156
# Evaluating model on 2 random 2 way one-shot learning tasks ...
#
# Got an average of 0.0% 2 way one-shot learning accuracy

# %%
XNIR,yNIR,cNIR = loadimgs('/content/nir/')
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 139.25it/s]
# 100%|██████████| 1/1 [00:00<00:00, 160.55it/s]
# 100%|██████████| 1/1 [00:00<00:00, 217.38it/s]
# 100%|██████████| 1/1 [00:00<00:00, 250.27it/s]
# 100%|██████████| 1/1 [00:00<00:00, 245.94it/s]
# 100%|██████████| 1/1 [00:00<00:00, 193.45it/s]
# 100%|██████████| 1/1 [00:00<00:00, 188.33it/s]
# 100%|██████████| 1/1 [00:00<00:00, 196.62it/s]
# 100%|██████████| 1/1 [00:00<00:00, 131.90it/s]
# 100%|██████████| 1/1 [00:00<00:00, 238.84it/s]
# 100%|██████████| 1/1 [00:00<00:00, 97.03it/s]
# 100%|██████████| 1/1 [00:00<00:00, 350.37it/s]
# 100%|██████████| 1/1 [00:00<00:00, 387.72it/s]
# 100%|██████████| 1/1 [00:00<00:00, 174.63it/s]
# 100%|██████████| 1/1 [00:00<00:00, 257.86it/s]
# 100%|██████████| 1/1 [00:00<00:00, 1191.23it/s]
# 100%|██████████| 1/1 [00:00<00:00, 217.22it/s]
# 100%|██████████| 1/1 [00:00<00:00, 361.20it/s]
# 100%|██████████| 1/1 [00:00<00:00, 472.38it/s]
# 100%|██████████| 1/1 [00:00<00:00, 504.55it/s]
# loading alphabet: New folder
# alphabet_path /content/nir/New folder
# letter nir_4
# letter nir_14
# letter nir_15
# letter nir_16
# letter nir_17
# letter nir_11
# letter nir_8
# letter nir_20
# letter nir_3
# letter nir_6
# letter nir_10
# letter nir_18
# letter nir_9
# letter nir_13
# letter nir_2
# letter nir_5
# letter nir_1
# letter nir_12
# letter nir_7
# letter nir_19
# (20, 128, 128, 3)

# %%
XVIS,yVIS,cVIS = loadimgs('/content/vis/')
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 80.78it/s]
# 100%|██████████| 1/1 [00:00<00:00, 82.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 191.43it/s]
# 100%|██████████| 1/1 [00:00<00:00, 104.79it/s]
# 100%|██████████| 1/1 [00:00<00:00, 217.56it/s]
# 100%|██████████| 1/1 [00:00<00:00, 111.45it/s]
# 100%|██████████| 1/1 [00:00<00:00, 157.71it/s]
# 100%|██████████| 1/1 [00:00<00:00, 287.03it/s]
# 100%|██████████| 1/1 [00:00<00:00, 665.87it/s]
# 100%|██████████| 1/1 [00:00<00:00, 917.79it/s]
# 100%|██████████| 1/1 [00:00<00:00, 292.31it/s]
# 100%|██████████| 1/1 [00:00<00:00, 147.45it/s]
# 100%|██████████| 1/1 [00:00<00:00, 213.94it/s]
# 100%|██████████| 1/1 [00:00<00:00, 283.65it/s]
# 100%|██████████| 1/1 [00:00<00:00, 305.24it/s]
# 100%|██████████| 1/1 [00:00<00:00, 325.64it/s]
# 100%|██████████| 1/1 [00:00<00:00, 247.06it/s]
# 100%|██████████| 1/1 [00:00<00:00, 302.71it/s]
# 100%|██████████| 1/1 [00:00<00:00, 313.15it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# loading alphabet: New folder
# alphabet_path /content/vis/New folder
# letter vis_16
# letter vis_2
# letter vis_1
# letter vis_13
# letter vis_17
# letter vis_11
# letter vis_6
# letter vis_14
# letter vis_3
# letter vis_4
# letter vis_7
# letter vis_20
# letter vis_19
# letter vis_12
# letter vis_15
# letter vis_18
# letter vis_8
# letter vis_5
# letter vis_9
# letter vis_10
# 100%|██████████| 1/1 [00:00<00:00, 115.28it/s]
# (20, 128, 128, 3)

# %%
plt.subplot(121),plt.imshow(XVIS[19][0])
plt.title('Visible Image 0'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(XNIR[10][0])
plt.title('Infrared Image 0'), plt.xticks([]), plt.yticks([])
#plt.subplot(133),plt.imshow(XNIR[1][0])
#plt.title('Infrared Image 1'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
for i in range(20):
  MATCH = model.predict([XVIS[14].reshape(1,128,128,3), XNIR[i].reshape(1,128,128,3)])
  #print(MATCH*100)
  output = (100 - MATCH*100)
  print(i)
  print (output)
# Out:
# 0
# [[45.606857]]
# 1
# [[44.629105]]
# 2
# [[46.781437]]
# 3
# [[42.92391]]
# 4
# [[41.81018]]
# 5
# [[46.825726]]
# 6
# [[43.75157]]
# 7
# [[37.50461]]
# 8
# [[45.93368]]
# 9
# [[46.781437]]
# 10
# [[47.642593]]
# 11
# [[42.178036]]
# 12
# [[47.290154]]
# 13
# [[48.22106]]
# 14
# [[48.142517]]
# 15
# [[45.60549]]
# 16
# [[45.606857]]
# 17
# [[46.781437]]
# 18
# [[45.586117]]
# 19
# [[46.345818]]

# %%
MATCH = model.predict([XVIS[14].reshape(1,128,128,3), XNIR[11].reshape(1,128,128,3)])
output = (100 - MATCH*100)
print (output)
# Out:
# [[52.0916]]

# %%
for i in range(500, 900):
    from google.colab import files
    i = str(i)
    files.download('weights.'+i+'.h5')
    print(i)
